# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\GOPI\Documents\Mutual_Fund_Analytics\notebooks

# %%
import os

print(os.path.exists(r"C:\Users\GOPI\Documents\Mutual_Fund_Analytics\data\raw\fund_master.csv"))
# Out:
# True

# %%
df = pd.read_csv("../data/raw/HDFC_Top100.csv")

df.head()
# Out:
#          date       nav
# 0  19-06-2026  202.0761
# 1  18-06-2026  200.9565
# 2  17-06-2026  199.8302
# 3  16-06-2026  198.6152
# 4  15-06-2026  198.0320

# %%
import pandas as pd

df = pd.read_csv("../data/raw/SBI_Bluechip.csv")
print(df.head())
# Out:
#          date       nav
# 0  19-06-2026  105.9219
# 1  18-06-2026  105.9003
# 2  17-06-2026  105.8482
# 3  16-06-2026  105.8455
# 4  15-06-2026  105.8125

# %%
print(fund_master.head())
print(fund_master.columns)
# Out:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
#    expense_ratio_pct  exit_load_pct  min_sip_amount  min_lumpsum_amount  \
# ...

# %%
import pandas as pd

fund_master = pd.read_csv(
    "../data/raw/fund_master.csv",
    sep="\t"
)

print(fund_master.shape)
print(fund_master.head())
print(fund_master.columns)
# Out:
# (40, 15)
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# 2   Equity    Small Cap  Regular  2009-09-09       BSE 250 SmallCap TRI
# 3   Equity    Small Cap   Direct  2013-01-01       BSE 250 SmallCap TRI
# 4     Debt         Gilt  Regular  2000-12-30  CRISIL Dynamic Gilt Index
#
# ...

# %%
print(nav_history.columns)
print(nav_history.head())
print(nav_history.shape)
# Out:
# Index(['amfi_code', 'date', 'nav'], dtype='object')
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692
# (46000, 3)

# %%
master_codes = set(fund_master["amfi_code"])
nav_codes = set(nav_history["amfi_code"])

missing_codes = master_codes - nav_codes

print("Fund Master Codes:", len(master_codes))
print("NAV History Codes:", len(nav_codes))
print("Missing Codes:", len(missing_codes))

if len(missing_codes) > 0:
    print("Missing AMFI Codes:")
    print(sorted(missing_codes))
else:
    print("All AMFI codes are present in nav_history.")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'amfi_code'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 master_codes = set(fund_master["amfi_code"])
# ...

# %%
import requests
import pandas as pd

url = "https://api.mfapi.in/mf/125497"

response = requests.get(url)
data = response.json()

nav_df = pd.DataFrame(data["data"])

nav_df.to_csv(
    "../data/raw/hdfc_top100_live_nav.csv",
    index=False
)

print(nav_df.head())
# Out:
#          date        nav
# 0  22-06-2026  204.12630
# 1  19-06-2026  202.07610
# 2  18-06-2026  200.95650
# 3  17-06-2026  199.83020
# 4  16-06-2026  198.61520

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['Axis_Bluechip.csv', 'fund_master.csv', 'HDFC_Top100.csv', 'hdfc_top100_nav.csv', 'ICICI_Bluechip.csv', 'Kotak_Bluechip.csv', 'nav_history.csv', 'Nippon_LargeCap.csv', 'SBI_Bluechip.csv']

# %%
import pandas as pd

fund_master = pd.read_csv("../data/raw/fund_master.csv")
nav_history = pd.read_csv("../data/raw/nav_history.csv")

print(fund_master.shape)
print(nav_history.shape)
# Out:
# (40, 1)
# (46000, 3)

# %%
print(fund_master.columns)
# Out:
# Index(['amfi_code\tfund_house\tscheme_name\tcategory\tsub_category\tplan\tlaunch_date\tbenchmark\texpense_ratio_pct\texit_load_pct\tmin_sip_amount\tmin_lumpsum_amount\tfund_manager\trisk_category\tsebi_category_code'], dtype='object')

# %%
fund_master.head()
# Out:
#   amfi_code\tfund_house\tscheme_name\tcategory\tsub_category\tplan\tlaunch_date\tbenchmark\texpense_ratio_pct\texit_load_pct\tmin_sip_amount\tmin_lumpsum_amount\tfund_manager\trisk_category\tsebi_category_code
# 0  119551\tSBI Mutual Fund\tSBI Bluechip Fund - R...
# 1  119552\tSBI Mutual Fund\tSBI Bluechip Fund - D...
# 2  119598\tSBI Mutual Fund\tSBI Small Cap Fund - ...
# 3  119599\tSBI Mutual Fund\tSBI Small Cap Fund - ...
# 4  119120\tSBI Mutual Fund\tSBI Magnum Gilt Fund ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3105 entries, 0 to 3104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3105 non-null   object
#  1   nav     3105 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 48.6+ KB

# %%
df.describe()
# Out:
#                nav
# count  3105.000000
# mean     90.417733
# std      60.621453
# min      12.777500
# 25%      40.297300
# 50%      61.554800
# 75%     130.847700
# max     214.676700

# %%
df['date'] = pd.to_datetime(df['date'], dayfirst=True)

df.head()
# Out:
#         date       nav
# 0 2026-06-19  202.0761
# 1 2026-06-18  200.9565
# 2 2026-06-17  199.8302
# 3 2026-06-16  198.6152
# 4 2026-06-15  198.0320

# %%
plt.figure(figsize=(12,5))

plt.plot(df['date'], df['nav'])

plt.title("HDFC Top 100 NAV Trend")
plt.xlabel("Date")
plt.ylabel("NAV")

plt.show()

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\GOPI\Documents\Mutual_Fund_Analytics\notebooks

# %%
import pandas as pd

fund_master = pd.read_csv(
    "../data/raw/fund_master.csv",
    sep="\t"
)

print(fund_master.columns.tolist())
# Out:
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']

# %%
# Convert fund_master.csv from Tab-Separated to Normal CSV

import pandas as pd

# Read the tab-separated file
fund_master = pd.read_csv(
    "../data/raw/fund_master.csv",
    sep="\t"
)

# Overwrite the same file as a normal CSV
fund_master.to_csv(
    "../data/raw/fund_master.csv",
    index=False
)

print("fund_master.csv converted successfully")
# Out:
# fund_master.csv converted successfully

# %%
import pandas as pd

df = pd.read_csv("../data/raw/fund_master.csv")

print(df.columns.tolist())
print(df.head())
# Out:
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# 1   Equity    Large Cap   Direct  2013-01-01              NIFTY 100 TRI
# ...

# %%
#   Unique Fund Houses

print("Unique Fund Houses")

print(fund_master["fund_house"].unique())

print("\nCount:", fund_master["fund_house"].nunique())
# Out:
# Unique Fund Houses
# ['SBI Mutual Fund' 'HDFC Mutual Fund' 'ICICI Prudential MF'
#  'Nippon India MF' 'Kotak Mahindra MF' 'Axis Mutual Fund'
#  'Aditya Birla Sun Life MF' 'UTI Mutual Fund' 'Mirae Asset MF'
#  'DSP Mutual Fund']
#
# Count: 10

# %%
# Categories

print("Categories")

print(fund_master["category"].unique())
# Out:
# Categories
# ['Equity' 'Debt']

# %%
# Sub Categories

print("Sub Categories")

print(fund_master["sub_category"].unique())
# Out:
# Sub Categories
# ['Large Cap' 'Small Cap' 'Gilt' 'Mid Cap' 'Short Duration' 'Value'
#  'Liquid' 'Index/ETF' 'Flexi Cap' 'Index' 'Large & Mid Cap' 'ELSS']

# %%
# Risk Grades

print("Risk Categories")

print(fund_master["risk_category"].unique())
# Out:
# Risk Categories
# ['Moderate' 'Very High' 'Low' 'High' 'Moderately High']

# %%
# Count by Risk Category

fund_master["risk_category"].value_counts()
# Out:
# risk_category
# Moderate           16
# High                8
# Very High           6
# Low                 6
# Moderately High     4
# Name: count, dtype: int64

# %%
# nav_history.csv

import pandas as pd

nav_history = pd.read_csv("../data/raw/nav_history.csv")

print(nav_history.columns.tolist())
print(nav_history.head())
# Out:
# ['amfi_code', 'date', 'nav']
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
import pandas as pd

nav_history = pd.read_csv("../data/raw/nav_history.csv")

print("Total NAV History Records:", len(nav_history))
print(nav_history.shape)
# Out:
# Total NAV History Records: 46000
# (46000, 3)

# %%
# Check Shapes

print("Fund Master Shape:", fund_master.shape)
print("NAV History Shape:", nav_history.shape)
# Out:
# Fund Master Shape: (40, 15)
# NAV History Shape: (46000, 3)

# %%
# AMFI Validation Code


master_codes = set(fund_master["amfi_code"])

nav_codes = set(nav_history["amfi_code"])

missing_codes = master_codes - nav_codes

print("Total Fund Master Codes:", len(master_codes))
print("Total NAV Codes:", len(nav_codes))
print("Missing Codes:", len(missing_codes))
# Out:
# Total Fund Master Codes: 40
# Total NAV Codes: 40
# Missing Codes: 0

# %%
# Show Missing Codes

print(missing_codes)
# Out:
# set()

# %%
print("="*50)
print("DAY 1 VALIDATION SUMMARY")
print("="*50)

print("Fund Houses:",
      fund_master["fund_house"].nunique())

print("Categories:",
      fund_master["category"].nunique())

print("Sub Categories:",
      fund_master["sub_category"].nunique())

print("Risk Categories:",
      fund_master["risk_category"].nunique())

print("Missing AMFI Codes:",
      len(missing_codes))
# Out:
# ...
# DAY 1 VALIDATION SUMMARY
# ...
# Fund Houses: 10
# Categories: 2
# Sub Categories: 12
# Risk Categories: 5
# Missing AMFI Codes: 0
